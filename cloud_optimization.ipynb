# %%
# !pip install google-generativeai

# %%
import google.generativeai as palm
import os

# %%
#@title Insert PaLM API Key here
palm.configure(api_key='AIzaSyAFr2u1xEl3Y8fLDFfhzWQsO6RqaL158bA')

# %%
# Use the palm.list_models function to find available models
# PaLM 2 available in 4 sizes: Gecko, Otter, Bison and Unicorn (largest)
# https://developers.generativeai.google/models/language

models = [m for m in palm.list_models() if 'generateText' in m.supported_generation_methods]
model = models[0].name
print(model)
# Out:
# models/text-bison-001

# %%
# !pip install gradio

# %%
#@title Gradio App
import gradio as gr
import os
from fpdf import FPDF
import google.generativeai as palm

# load model
# PaLM API Key here
palm.configure(api_key='AIzaSyAFr2u1xEl3Y8fLDFfhzWQsO6RqaL158bA')


# define completion function
def get_completion(code_snippet):

  python_code_examples = f"""
  ---------------------
  Tools:
<<all_tools>>
  Example 1: Code Snippet
  # Solution

The following architecture diagram shows a cost-optimized solution for Company ABC to move their existing Java-based website to AWS. The solution includes the following components:



## Infrastructure Details and Pricing

The following table shows the estimated monthly costs for the proposed architecture. The costs are based on the following assumptions:



| Service           | Estimated Monthly Cost |
| ------------------ | ------------------------ |
|               |
|                |

## Pricing Strategies for DEV, TEST, and PROD Environments

The following pricing strategies can be used to handle the DEV, TEST, and PROD environments for the proposed architecture:

- **DEV Environment:** The DEV environment can be hosted on Amazon EC2 instances in the AWS Free Tier. This will allow Company ABC to develop and test their website application without incurring any costs.
- **TEST Environment:** The TEST environment can be hosted on Amazon EC2 instances in the AWS On-Demand pricing model. This will allow Company ABC to test their website application under realistic load conditions.
- **PROD Environment:** The PROD environment can be hosted on Amazon EC2 instances in the AWS Reserved Instances pricing model. This will allow Company ABC to save money on their monthly costs by committing to a certain amount of resources for a certain period of time.

## Advantages of the Proposed Architecture

The proposed architecture has a number of advantages over a traditional on-premises deployment, including:

- **Cost savings:** The proposed architecture can help Company ABC save money on their monthly costs by taking advantage of AWS's pay-as-you-go pricing model.
- **Scalability:** The proposed architecture is scalable and can easily be provisioned to handle increased traffic.
- **Reliability:** The proposed architecture is reliable and can be used to ensure that the website application is always available to users.
- **Security:** The proposed architecture is secure and can be used to protect the website application from unauthorized access.

## Conclusion

The proposed architecture is a cost-optimized solution for Company ABC to move their existing Java-based website to AWS. The solution is scalable, reliable, and secure, and can help Company ABC save money on their monthly costs.

Example 2: Code Snippet

# Cost-Optimized Architecture for Healthcare System

## Solution

The following architecture diagram illustrates a cost-optimized solution for a healthcare system. The solution encompasses various components designed to provide efficient healthcare services:

- **Amazon EC2** instances for hosting the healthcare system's web application and services. Estimated cost: $2,000 per month.
- **Amazon RDS** for MySQL database to store patient records and medical data securely. Estimated cost: $1,000 per month.
- **Amazon Elastic Load Balancing** (ELB) for distributing traffic and ensuring high availability. Estimated cost: $200 per month.
- **Amazon CloudFront** for caching static medical resources and optimizing performance. Estimated cost: $200 per month.
- **Amazon API Gateway** for creating and managing RESTful APIs for healthcare services. Estimated cost: $200 per month.
- **Amazon Cognito** for robust identity and access management (IAM) to safeguard patient data and authentication. Estimated cost: $200 per month.
- **Amazon CloudWatch** for monitoring system performance and ensuring operational excellence. Estimated cost: $200 per month.
- **Amazon Simple Notification Service** (SNS) to send critical healthcare alerts and notifications. Estimated cost: $200 per month.

## Infrastructure Details and Pricing

The following table provides an overview of estimated monthly costs for the proposed architecture:

- The healthcare system is hosted on Amazon EC2 instances with specifications similar to m5.large instances, including 2 vCPUs, 8 GB of RAM, and 20 GB of storage.
- The patient database is hosted on a single Amazon RDS for MySQL instance with specifications similar to db.m5.large instances, including 2 vCPUs, 8 GB of RAM, and 20 GB of storage.
- The healthcare system is anticipated to serve 100,000 patients per month.

| Service           | Estimated Monthly Cost |
| ------------------ | ------------------------ |
|              |

## Pricing Strategies for DEV, TEST, and PROD Environments

To efficiently manage costs and resources, consider the following pricing strategies for various environments:

- **DEV Environment:** Develop and test the healthcare system on Amazon EC2 instances in the AWS Free Tier, ensuring no additional costs during development.
- **TEST Environment:** Host the TEST environment on Amazon EC2 instances in the AWS On-Demand pricing model to simulate realistic load conditions for testing.
- **PROD Environment:** For production, consider using Amazon EC2 instances in the AWS Reserved Instances pricing model to reduce monthly costs while maintaining consistent healthcare service.

## Advantages of the Proposed Architecture

The proposed architecture offers several advantages, especially critical in healthcare:

- **Cost Savings:** The architecture leverages AWS's pay-as-you-go pricing model to provide cost optimization.
- **Scalability:** Designed to accommodate increased healthcare system usage and expanding patient data.
- **Reliability:** Ensures high availability, data integrity, and operational excellence for efficient healthcare services.
- **Security:** Amazon Cognito provides robust identity and access management, ensuring patient data protection and HIPAA compliance.

## Conclusion

The proposed architecture is a cost-optimized solution for a healthcare system, focused on providing efficient healthcare services while managing costs effectively. The architecture is designed to be scalable, reliable, and secure, meeting the demands of healthcare while offering potential cost savings through efficient resource management.

Use this below reference tool for any AWS related question to help customers understand best practices on building on AWS. It will use the relevant context from the AWS Well-Architected Framework to answer the customer's query. The input is the customer's question. The tool returns an answer for the customer using the relevant context.
refer the below resources for your usecase for the services and cost calculation
input_text =
Resources:

https://docs.aws.amazon.com/ec2/?nc2=h_ql_doc_ec2
https://aws.amazon.com/pricing/?aws-products-pricing.sort-by=item.additionalFields.productNameLowercase&aws-products-pricing.sort-order=asc&awsf.Free%20Tier%20Type=*all&awsf.tech-category=*all
https://d1.awsstatic.com/whitepapers/aws_pricing_overview.pdf

similary to above code snippet ,get a cost-optimized architecture and cost for your case 

  """

  prompt = f"""
   Your task is to act as aws solution architecture and aws price calculator.
I'll give you a usecase.
Your job is to get a cost-optimized solution architecture and You can format the provided text using Markdown to create a nicely structured document 
1) architecture should includes the necessary  components needed for the usecase of cost-optimized 
2)following table should shows the estimated monthly cost of this architecture with 1000 monthly visitors
3)By using this cost-optimized solution architecture tell the benefits
4)final total cost 
Also, compute the final output of the cost.
usecase example is shared below:
  {python_code_examples}
  ####
  Code Snippet is shared below, delimited with triple backticks:
  ```
  {code_snippet}
  ```
  """

  completion = palm.generate_text(
      model=model,
      prompt=prompt,
      temperature=0,
      # The maximum length of the response
      )
  response = completion.result
  if response:
        pdf=FPDF()
        pdf.add_page()
        pdf.set_font("Arial", size=12)
        pdf.multi_cell(0, 10, response)
        pdf.output("aws_solution.pdf")
        
  return response

# define app UI
iface = gr.Interface(fn=get_completion, inputs=[gr.Textbox(label="Usecase",lines=5)],
                    outputs=[gr.Textbox(label="Explanation Here with Cost",lines=5)],
                    title="aws solution architecture final year project"
                    )

iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
class AWSWellArchTool(Tool):
    name = "well_architected_tool"
    description = "Use this tool for any AWS related question to help customers understand best practices on building on AWS. It will use the relevant context from the AWS Well-Architected Framework to answer the customer's query. The input is the customer's question. The tool returns an answer for the customer using the relevant context."
    inputs = ["text"]
    outputs = ["text"]

    def qa_chain(self):
        prompt_template = """Use the following pieces of context to answer the question at the end.

        {context}

        Question: {question}
        Answer:"""
        PROMPT = PromptTemplate(
            template=prompt_template, input_variables=["context", "question"]
        )

        class ContentHandler(LLMContentHandler):
            content_type = "application/json"
            accepts = "application/json"

            def transform_input(self, prompt: str, model_kwargs: Dict) -> bytes:
                # clean prompt
                prompt = prompt.replace("\\n,", "").replace("\n", "").strip()

                payload = {
                    "prompt": prompt,
                    "maxTokens": 2048,
                    "temperature": 0.7,
                    "numResults": 1,
                }

                payload = json.dumps(payload).encode("utf-8")
                return payload

            def transform_output(self, output: bytes) -> str:
                response_json = json.loads(output.read().decode("utf-8"))
                return response_json["completions"][0]["data"]["text"]

        content_handler = ContentHandler()
        # Setup chain
        chain = load_qa_chain(
            llm=SagemakerEndpoint(
                endpoint_name="j2-grande-instruct",
                region_name="us-east-1",
                credentials_profile_name="default", 
                content_handler=content_handler,
            ),
            prompt=PROMPT,
        )

        return chain

    def __call__(self, query):
        chain = self.qa_chain()
        # Find docs
        embeddings = HuggingFaceEmbeddings()
        vectorstore = FAISS.load_local("local_index", embeddings)
        docs = vectorstore.similarity_search(query)

        doc_sources_string = ""
        for doc in docs:
            doc_sources_string += doc.metadata["source"] + "\n"

        results = chain(
            {"input_documents": docs, "question": query}, return_only_outputs=True
        )

        resp_json = {"ans": str(results["output_text"]), "docs": doc_sources_string}

        return resp_json
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6932\1345103626.py in <module>
# ----> 1 class AWSWellArchTool(Tool):
#       2     name = "well_architected_tool"
#       3     description = "Use this tool for any AWS related question to help customers understand best practices on building on AWS. It will use the relevant context from the AWS Well-Architected Framework to answer the customer's query. The input is the customer's question. The tool returns an answer for the customer using the relevant context."
#       4     inputs = ["text"]
#       5     outputs = ["text"]
#
# NameError: name 'Tool' is not defined

# %%
query = "How can I design secure VPCs?"
well_arch_tool = AWSWellArchTool()
well_arch_tool(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6932\139296956.py in <module>
#       1 query = "How can I design secure VPCs?"
# ----> 2 well_arch_tool = AWSWellArchTool()
#       3 well_arch_tool(query)
#
# NameError: name 'AWSWellArchTool' is not defined

# %%
##do not touch this

# %%
#@title Gradio App
import gradio as gr
import os
from fpdf import FPDF
import google.generativeai as palm

# load model
# PaLM API Key here
palm.configure(api_key='AIzaSyAFr2u1xEl3Y8fLDFfhzWQsO6RqaL158bA')


# define completion function
def get_completion(code_snippet):

  python_code_examples = f"""
  ---------------------
  Example 1: Code Snippet
  # Solution

The following architecture diagram shows a cost-optimized solution for Company ABC to move their existing Java-based website to AWS. The solution includes the following components:



## Infrastructure Details and Pricing

The following table shows the estimated monthly costs for the proposed architecture. The costs are based on the following assumptions:



| Service           | Estimated Monthly Cost |
| ------------------ | ------------------------ |
|               |
|                |

## Pricing Strategies for DEV, TEST, and PROD Environments

The following pricing strategies can be used to handle the DEV, TEST, and PROD environments for the proposed architecture:

- **DEV Environment:** The DEV environment can be hosted on Amazon EC2 instances in the AWS Free Tier. This will allow Company ABC to develop and test their website application without incurring any costs.
- **TEST Environment:** The TEST environment can be hosted on Amazon EC2 instances in the AWS On-Demand pricing model. This will allow Company ABC to test their website application under realistic load conditions.
- **PROD Environment:** The PROD environment can be hosted on Amazon EC2 instances in the AWS Reserved Instances pricing model. This will allow Company ABC to save money on their monthly costs by committing to a certain amount of resources for a certain period of time.

## Advantages of the Proposed Architecture

The proposed architecture has a number of advantages over a traditional on-premises deployment, including:

- **Cost savings:** The proposed architecture can help Company ABC save money on their monthly costs by taking advantage of AWS's pay-as-you-go pricing model.
- **Scalability:** The proposed architecture is scalable and can easily be provisioned to handle increased traffic.
- **Reliability:** The proposed architecture is reliable and can be used to ensure that the website application is always available to users.
- **Security:** The proposed architecture is secure and can be used to protect the website application from unauthorized access.

## Conclusion

The proposed architecture is a cost-optimized solution for Company ABC to move their existing Java-based website to AWS. The solution is scalable, reliable, and secure, and can help Company ABC save money on their monthly costs.

Example 2: Code Snippet

# Cost-Optimized Architecture for Healthcare System

## Solution

The following architecture diagram illustrates a cost-optimized solution for a healthcare system. The solution encompasses various components designed to provide efficient healthcare services:

- **Amazon EC2** instances for hosting the healthcare system's web application and services. Estimated cost: $2,000 per month.
- **Amazon RDS** for MySQL database to store patient records and medical data securely. Estimated cost: $1,000 per month.
- **Amazon Elastic Load Balancing** (ELB) for distributing traffic and ensuring high availability. Estimated cost: $200 per month.
- **Amazon CloudFront** for caching static medical resources and optimizing performance. Estimated cost: $200 per month.
- **Amazon API Gateway** for creating and managing RESTful APIs for healthcare services. Estimated cost: $200 per month.
- **Amazon Cognito** for robust identity and access management (IAM) to safeguard patient data and authentication. Estimated cost: $200 per month.
- **Amazon CloudWatch** for monitoring system performance and ensuring operational excellence. Estimated cost: $200 per month.
- **Amazon Simple Notification Service** (SNS) to send critical healthcare alerts and notifications. Estimated cost: $200 per month.

## Infrastructure Details and Pricing

The following table provides an overview of estimated monthly costs for the proposed architecture:

- The healthcare system is hosted on Amazon EC2 instances with specifications similar to m5.large instances, including 2 vCPUs, 8 GB of RAM, and 20 GB of storage.
- The patient database is hosted on a single Amazon RDS for MySQL instance with specifications similar to db.m5.large instances, including 2 vCPUs, 8 GB of RAM, and 20 GB of storage.
- The healthcare system is anticipated to serve 100,000 patients per month.

| Service           | Estimated Monthly Cost |
| ------------------ | ------------------------ |
| Amazon EC2        | $2,000.00               |
| Amazon RDS        | $1,000.00               |
| Amazon ELB        | $200.00                 |
| Amazon CloudFront | $200.00                 |
| Amazon API Gateway | $200.00                |
| Amazon Cognito    | $200.00                 |
| Amazon CloudWatch | $200.00                 |
| Amazon SNS        | $200.00                 |
| Total             | $4,000.00               |

## Pricing Strategies for DEV, TEST, and PROD Environments

To efficiently manage costs and resources, consider the following pricing strategies for various environments:

- **DEV Environment:** Develop and test the healthcare system on Amazon EC2 instances in the AWS Free Tier, ensuring no additional costs during development.
- **TEST Environment:** Host the TEST environment on Amazon EC2 instances in the AWS On-Demand pricing model to simulate realistic load conditions for testing.
- **PROD Environment:** For production, consider using Amazon EC2 instances in the AWS Reserved Instances pricing model to reduce monthly costs while maintaining consistent healthcare service.

## Advantages of the Proposed Architecture

The proposed architecture offers several advantages, especially critical in healthcare:

- **Cost Savings:** The architecture leverages AWS's pay-as-you-go pricing model to provide cost optimization.
- **Scalability:** Designed to accommodate increased healthcare system usage and expanding patient data.
- **Reliability:** Ensures high availability, data integrity, and operational excellence for efficient healthcare services.
- **Security:** Amazon Cognito provides robust identity and access management, ensuring patient data protection and HIPAA compliance.

## Conclusion

The proposed architecture is a cost-optimized solution for a healthcare system, focused on providing efficient healthcare services while managing costs effectively. The architecture is designed to be scalable, reliable, and secure, meeting the demands of healthcare while offering potential cost savings through efficient resource management.

similary to above code snippet ,get a cost-optimized architecture and cost for your case


  """

  prompt = f"""
   Your task is to act as aws solution architecture.
I'll give you a usecase.
Your job is to get a cost-optimized solution architecture and You can format the provided text using Markdown to create a nicely structured document 
1) architecture should includes the necessary  components needed for the usecase of cost-optimized 
2)following table should shows the estimated monthly cost of this architecture with 1000 monthly visitors
3)By using this cost-optimized solution architecture tell the benefits
4)final total cost 
Also, compute the final output of the code.
usecase example is shared below:
  {python_code_examples}
  ####
  Code Snippet is shared below, delimited with triple backticks:
  ```
  {code_snippet}
  ```
  """

  completion = palm.generate_text(
      model=model,
      prompt=prompt,
      temperature=0,
      # The maximum length of the response
      max_output_tokens=500,
      )
  response = completion.result
  return response

# define app UI
iface = gr.Interface(fn=get_completion, inputs=[gr.Textbox(label="Insert Code Snippet",lines=5)],
                    outputs=[gr.Textbox(label="Explanation Here",lines=5)],
                    title="aws solution architecture final year project"
                    )

iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7868
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
